# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as patches
import matplotlib.cm as cm
import time
import copy
import os

#job_id = int(os.environ['SLURM_ARRAY_JOB_ID'])
#task_id = int(os.environ['SLURM_ARRAY_TASK_ID'])
#job_id = 1
#task_id=1


def truep(x):
    return  np.exp(-0.5*(0.03*x[0]**2+(x[1]+0.03*(x[0]**2-100))**2))

# %%
def get_children(node):
    ##same level, spilit vertically
    if np.floor(np.log2(node[0]+1)) == np.floor(np.log2(node[1]+1)):
        children = [[2*node[0]+1, node[1]], [2*node[0]+2, node[1]]]
    elif np.floor(np.log2(node[0]+1)) == np.floor(np.log2(node[1]+1)) + 1:
        children = [[node[0], 2*node[1]+1], [node[0], 2*node[1]+2]]
    else:
        raise Exception('invalid node')
    return children

# %%
def get_parent(node):
    ##same level
    if np.floor(np.log2(node[0]+1)) == np.floor(np.log2(node[1]+1)):
        parent = [node[0], int((node[1]-1)/2)]
    elif np.floor(np.log2(node[0]+1)) == np.floor(np.log2(node[1]+1)) + 1:
        parent = [int((node[0]-1)/2), node[1]]
    else:
        raise Exception('invalid node')
    return parent

# %%
def get_ss(node, right_lim = False):
    
    ll = np.floor(np.log2(np.array(node)+1))
    if node == [0,0]:
        ss = [-M,-M]
    else:
        ss = 2*M*((node-2**ll+1)/2**ll)-M
    if right_lim == True:
        return (ss, ss + 2*M/np.power(2,ll), ll)
    else:
        return ss

# %% [markdown]
# # Run experiment

# %%
#T = 1000000
T=int(1e5)
explorefactor = 3
threshold = 10
M = 10
alpha = 0.99

xx = np.zeros((2,T))
pp = np.zeros((T))
q = [1]
unnorm_q = [1]
nn = [0]
unnorm_weights= [0]
lll=[1]
index_list = [[]]

children = [[0,0]]
num_partition = []
Z_hat = []
total_ESS = []
zz = [0]


np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

# %%
save_index = np.array([int(x) for x in np.linspace(0, 5e5, 10000)])


for tt in range(T):
    ii=[int(0),int(0)]
    arm = np.random.choice(len(children), 1, p=np.array(q))[0] #choose the arm 
    ii = [children[arm][0],children[arm][1]]
    ss = get_ss(ii, right_lim = True)
    ll = ss[-1]
    rr = np.random.uniform(0,1,2)
    xx[:,tt] = ss[0] + 2*M*rr/(np.power(2,ll))
    pp[tt] = truep(xx[:,tt])  
    v = pp[tt]*((2*M/2**ll[0])*(2*M/2**ll[1]))
    #update statistics
    index_list[arm].append(tt) 
    
### need to update total rather than q
    ind = index_list[arm]
    area = (2*M/2**ll[0])*(2*M/2**ll[1])
    total = (pp[ind]*area).sum()
    weights = total/max(len(ind),1)
    
    nn[arm] = nn[arm] + 1

    unnorm_weights[arm] = weights   
    
    unnorm_q = unnorm_weights + explorefactor/np.array(lll)*np.sqrt(np.log(tt+1))/nn
    
    q = (unnorm_q/sum(unnorm_q)).tolist()

    zz[arm] = weights
    
    if (len(ind) > threshold) :

        #ind = index_list[arm]
     #   ll = np.floor(np.log2(np.array(ii)+1))
     #   total = (pp[ind]/((2*M/2**ll[0])*(2*M/2**ll[1]))).sum()
        total2 = ((pp[ind]*area)**2).sum()
        ess = np.exp(2*np.log(total) - np.log(total2))
    #    zz[arm] = total/len(ind)
        total_z = np.sum(zz) #if tt < 1 else z_hat
        if ess < alpha*len(ind)*zz[arm]/total_z *100 :
            children.remove(ii)
            #update statistics 
            new_child = get_children(ii)
            children.extend(new_child)
            
            #adjust potential child nodes
            new_id = []
            sample_range = ss
     #       ll = sample_range[-1]
            if ll[0] == ll[1]:
                newid_l = np.array(index_list[arm])[np.where( \
                         (xx[0, index_list[arm]] >= sample_range[0][0]) &\
                         (xx[0, index_list[arm]] < (sample_range[1][0]+sample_range[0][0])/2))\
                          ].tolist()
                newid_r = np.array(index_list[arm])[np.where( \
                         (xx[0, index_list[arm]] >= (sample_range[1][0]+sample_range[0][0])/2) &\
                         (xx[0, index_list[arm]] <= sample_range[1][0]) )].tolist()

            else:
                newid_l = np.array(index_list[arm])[np.where( \
                         (xx[1, index_list[arm]] >= sample_range[0][1]) &\
                         (xx[1, index_list[arm]] < (sample_range[1][1]+sample_range[0][1])/2 ))[0]].tolist()
                newid_r = np.array(index_list[arm])[np.where(  \
                         (xx[1, index_list[arm]] >= (sample_range[1][1]+sample_range[0][1])/2) &\
                         (xx[1, index_list[arm]] <= sample_range[1][1]))].tolist() 


            new_zzl = (pp[newid_l]*area/2).sum()
            new_zzr = (pp[newid_r]*area/2).sum()
            new_id = [newid_l, newid_r]   
            new_zz = [new_zzl, new_zzr]

            index_list.remove(index_list[arm])
            index_list.extend(new_id)
            zz.pop(arm)
            zz.extend(new_zz)
            
            
            nn.pop(arm)
            new_nn = np.array([max(1e-6,len(newid_l)), max(1e-6,len(newid_r))]) 
            nn.extend(new_nn)
            new_weights = np.array(new_zz)/new_nn
            
            lll.pop(arm)
            new_ll = get_ss(new_child[0], right_lim = True)[-1]
            lll.extend(np.array([np.prod(new_ll + 1), np.prod(new_ll + 1)]))
            unnorm_weights.pop(arm)
            unnorm_weights.extend(new_weights)
            unnorm_q = unnorm_q.tolist()
            unnorm_q.pop(arm)
            unnorm_q.extend(new_weights + explorefactor/np.prod(new_ll + 1)*\
                     np.sqrt(np.log(tt+1)/new_nn))
            q = (unnorm_q/sum(unnorm_q)).tolist()
        
       
    
    if (tt in save_index) & (tt>1): 
        print('iteration %d' %tt)
        Z_hat.append(sum(zz))
        total, total2 = [], []
        for k in range(len(children)):
            level = np.floor(np.log2(np.array(children[k])+1))
            ind = index_list[k]
            area = (2*M/2**level[0])*(2*M/2**level[1])
            tmp = (pp[ind]*area).sum()
            total.append(tmp)
            total2.append(((pp[ind]*area)**2).sum())
            num_partition.append(len(children))
        total_ESS.append(np.exp(2*np.log(sum(total))- np.log(sum(total2)))/tt)
# Out:
# iteration 50
# iteration 100
# iteration 150
# iteration 200
# iteration 250
# iteration 300
# iteration 350
# iteration 400
# iteration 450
# iteration 500
# iteration 550
# iteration 600
# iteration 650
# iteration 700
# iteration 750
# iteration 800
# iteration 850
# iteration 900
# iteration 950
# iteration 1000
# iteration 1050
# iteration 1100
# iteration 1150
# iteration 1200
# iteration 1250
# iteration 1300
# iteration 1350
# iteration 1400
# iteration 1450
# iteration 1500
# iteration 1550
# iteration 1600
# iteration 1650
# iteration 1700
# iteration 1750
# iteration 1800
# iteration 1850
# iteration 1900
# iteration 1950
# iteration 2000
# iteration 2050
# iteration 2100
# iteration 2150
# iteration 2200
# iteration 2250
# iteration 2300
# iteration 2350
# iteration 2400
# iteration 2450
# iteration 2500
# iteration 2550
# iteration 2600
# iteration 2650
# iteration 2700
# iteration 2750
# iteration 2800
# iteration 2850
# iteration 2900
# iteration 2950
# iteration 3000
# iteration 3050
# iteration 3100
# iteration 3150
# iteration 3200
# iteration 3250
# iteration 3300
# iteration 3350
# iteration 3400
# iteration 3450
# iteration 3500
# iteration 3550
# iteration 3600
# iteration 3650
# iteration 3700
# iteration 3750
# iteration 3800
# iteration 3850
# iteration 3900
# iteration 3950
# iteration 4000
# iteration 4050
# iteration 4100
# iteration 4150
# iteration 4200
# iteration 4250
# iteration 4300
# iteration 4350
# iteration 4400
# iteration 4450
# iteration 4500
# iteration 4550
# iteration 4600
# iteration 4650
# iteration 4700
# iteration 4750
# iteration 4800
# iteration 4850
# iteration 4900
# iteration 4950
# iteration 5000
# iteration 5050
# iteration 5100
# iteration 5150
# iteration 5200
# iteration 5250
# iteration 5300
# iteration 5350
# iteration 5400
# iteration 5450
# iteration 5500
# iteration 5550
# iteration 5600
# iteration 5650
# iteration 5700
# iteration 5750
# iteration 5800
# iteration 5850
# iteration 5900
# iteration 5950
# iteration 6000
# iteration 6050
# iteration 6100
# iteration 6150
# iteration 6200
# iteration 6250
# iteration 6300
# iteration 6350
# iteration 6400
# iteration 6450
# iteration 6500
# iteration 6550
# iteration 6600
# iteration 6650
# iteration 6700
# iteration 6750
# iteration 6800
# iteration 6850
# iteration 6900
# iteration 6950
# iteration 7000
# iteration 7050
# iteration 7100
# iteration 7150
# iteration 7200
# iteration 7250
# iteration 7300
# iteration 7350
# iteration 7400
# iteration 7450
# iteration 7500
# iteration 7550
# iteration 7600
# iteration 7650
# iteration 7700
# iteration 7750
# iteration 7800
# iteration 7850
# iteration 7900
# iteration 7950
# iteration 8000
# iteration 8050
# iteration 8100
# iteration 8150
# iteration 8200
# iteration 8250
# iteration 8300
# iteration 8350
# iteration 8400
# iteration 8450
# iteration 8500
# iteration 8550
# iteration 8600
# iteration 8650
# iteration 8700
# iteration 8750
# iteration 8800
# iteration 8850
# iteration 8900
# iteration 8950
# iteration 9000
# iteration 9050
# iteration 9100
# iteration 9150
# iteration 9200
# iteration 9250
# iteration 9300
# iteration 9350
# iteration 9400
# iteration 9450
# iteration 9500
# iteration 9550
# iteration 9600
# iteration 9650
# iteration 9700
# iteration 9750
# iteration 9800
# iteration 9850
# iteration 9900
# iteration 9950
# iteration 10001
# iteration 10051
# iteration 10101
# iteration 10151
# iteration 10201
# iteration 10251
# iteration 10301
# iteration 10351
# iteration 10401
# iteration 10451
# iteration 10501
# iteration 10551
# iteration 10601
# iteration 10651
# iteration 10701
# iteration 10751
# iteration 10801
# iteration 10851
# iteration 10901
# iteration 10951
# iteration 11001
# iteration 11051
# iteration 11101
# iteration 11151
# iteration 11201
# iteration 11251
# iteration 11301
# iteration 11351
# iteration 11401
# iteration 11451
# iteration 11501
# iteration 11551
# iteration 11601
# iteration 11651
# iteration 11701
# iteration 11751
# iteration 11801
# iteration 11851
# iteration 11901
# iteration 11951
# iteration 12001
# iteration 12051
# iteration 12101
# iteration 12151
# iteration 12201
# iteration 12251
# iteration 12301
# iteration 12351
# iteration 12401
# iteration 12451
# iteration 12501
# iteration 12551
# iteration 12601
# iteration 12651
# iteration 12701
# iteration 12751
# iteration 12801
# iteration 12851
# iteration 12901
# iteration 12951
# iteration 13001
# iteration 13051
# iteration 13101
# iteration 13151
# iteration 13201
# iteration 13251
# iteration 13301
# iteration 13351
# iteration 13401
# iteration 13451
# iteration 13501
# iteration 13551
# iteration 13601
# iteration 13651
# iteration 13701
# iteration 13751
# iteration 13801
# iteration 13851
# iteration 13901
# iteration 13951
# iteration 14001
# iteration 14051
# iteration 14101
# iteration 14151
# iteration 14201
# iteration 14251
# iteration 14301
# iteration 14351
# iteration 14401
# iteration 14451
# iteration 14501
# iteration 14551
# iteration 14601
# iteration 14651
# iteration 14701
# iteration 14751
# iteration 14801
# iteration 14851
# iteration 14901
# iteration 14951
# iteration 15001
# iteration 15051
# iteration 15101
# iteration 15151
# iteration 15201
# iteration 15251
# iteration 15301
# iteration 15351
# iteration 15401
# iteration 15451
# iteration 15501
# iteration 15551
# iteration 15601
# iteration 15651
# iteration 15701
# iteration 15751
# iteration 15801
# iteration 15851
# iteration 15901
# iteration 15951
# iteration 16001
# iteration 16051
# iteration 16101
# iteration 16151
# iteration 16201
# iteration 16251
# iteration 16301
# iteration 16351
# iteration 16401
# iteration 16451
# iteration 16501
# iteration 16551
# iteration 16601
# iteration 16651
# iteration 16701
# iteration 16751
# iteration 16801
# iteration 16851
# iteration 16901
# iteration 16951
# iteration 17001
# iteration 17051
# iteration 17101
# iteration 17151
# iteration 17201
# iteration 17251
# iteration 17301
# iteration 17351
# iteration 17401
# iteration 17451
# iteration 17501
# iteration 17551
# iteration 17601
# iteration 17651
# iteration 17701
# iteration 17751
# iteration 17801
# iteration 17851
# iteration 17901
# iteration 17951
# iteration 18001
# iteration 18051
# iteration 18101
# iteration 18151
# iteration 18201
# iteration 18251
# iteration 18301
# iteration 18351
# iteration 18401
# iteration 18451
# iteration 18501
# iteration 18551
# iteration 18601
# iteration 18651
# iteration 18701
# iteration 18751
# iteration 18801
# iteration 18851
# iteration 18901
# iteration 18951
# iteration 19001
# iteration 19051
# iteration 19101
# iteration 19151
# iteration 19201
# iteration 19251
# iteration 19301
# iteration 19351
# iteration 19401
# iteration 19451
# iteration 19501
# iteration 19551
# iteration 19601
# iteration 19651
# iteration 19701
# iteration 19751
# iteration 19801
# iteration 19851
# iteration 19901
# iteration 19951
# iteration 20002
# iteration 20052
# iteration 20102
# iteration 20152
# iteration 20202
# iteration 20252
# iteration 20302
# iteration 20352
# iteration 20402
# iteration 20452
# iteration 20502
# iteration 20552
# iteration 20602
# iteration 20652
# iteration 20702
# iteration 20752
# iteration 20802
# iteration 20852
# iteration 20902
# iteration 20952
# iteration 21002
# iteration 21052
# iteration 21102
# iteration 21152
# iteration 21202
# iteration 21252
# iteration 21302
# iteration 21352
# iteration 21402
# iteration 21452
# iteration 21502
# iteration 21552
# iteration 21602
# iteration 21652
# iteration 21702
# iteration 21752
# iteration 21802
# iteration 21852
# iteration 21902
# iteration 21952
# iteration 22002
# iteration 22052
# iteration 22102
# iteration 22152
# iteration 22202
# iteration 22252
# iteration 22302
# iteration 22352
# iteration 22402
# iteration 22452
# iteration 22502
# iteration 22552
# iteration 22602
# iteration 22652
# iteration 22702
# iteration 22752
# iteration 22802
# iteration 22852
# iteration 22902
# iteration 22952
# iteration 23002
# iteration 23052
# iteration 23102
# iteration 23152
# iteration 23202
# iteration 23252
# iteration 23302
# iteration 23352
# iteration 23402
# iteration 23452
# iteration 23502
# iteration 23552
# iteration 23602
# iteration 23652
# iteration 23702
# iteration 23752
# iteration 23802
# iteration 23852
# iteration 23902
# iteration 23952
# iteration 24002
# iteration 24052
# iteration 24102
# iteration 24152
# iteration 24202
# iteration 24252
# iteration 24302
# iteration 24352
# iteration 24402
# iteration 24452
# iteration 24502
# iteration 24552
# iteration 24602
# iteration 24652
# iteration 24702
# iteration 24752
# iteration 24802
# iteration 24852
# iteration 24902
# iteration 24952
# iteration 25002
# iteration 25052
# iteration 25102
# iteration 25152
# iteration 25202
# iteration 25252
# iteration 25302
# iteration 25352
# iteration 25402
# iteration 25452
# iteration 25502
# iteration 25552
# iteration 25602
# iteration 25652
# iteration 25702
# iteration 25752
# iteration 25802
# iteration 25852
# iteration 25902
# iteration 25952
# iteration 26002
# iteration 26052
# iteration 26102
# iteration 26152
# iteration 26202
# iteration 26252
# iteration 26302
# iteration 26352
# iteration 26402
# iteration 26452
# iteration 26502
# iteration 26552
# iteration 26602
# iteration 26652
# iteration 26702
# iteration 26752
# iteration 26802
# iteration 26852
# iteration 26902
# iteration 26952
# iteration 27002
# iteration 27052
# iteration 27102
# iteration 27152
# iteration 27202
# iteration 27252
# iteration 27302
# iteration 27352
# iteration 27402
# iteration 27452
# iteration 27502
# iteration 27552
# iteration 27602
# iteration 27652
# iteration 27702
# iteration 27752
# iteration 27802
# iteration 27852
# iteration 27902
# iteration 27952
# iteration 28002
# iteration 28052
# iteration 28102
# iteration 28152
# iteration 28202
# iteration 28252
# iteration 28302
# iteration 28352
# iteration 28402
# iteration 28452
# iteration 28502
# iteration 28552
# iteration 28602
# iteration 28652
# iteration 28702
# iteration 28752
# iteration 28802
# iteration 28852
# iteration 28902
# iteration 28952
# iteration 29002
# iteration 29052
# iteration 29102
# iteration 29152
# iteration 29202
# iteration 29252
# iteration 29302
# iteration 29352
# iteration 29402
# iteration 29452
# iteration 29502
# iteration 29552
# iteration 29602
# iteration 29652
# iteration 29702
# iteration 29752
# iteration 29802
# iteration 29852
# iteration 29902
# iteration 29952
# iteration 30003
# iteration 30053
# iteration 30103
# iteration 30153
# iteration 30203
# iteration 30253
# iteration 30303
# iteration 30353
# iteration 30403
# iteration 30453
# iteration 30503
# iteration 30553
# iteration 30603
# iteration 30653
# iteration 30703
# iteration 30753
# iteration 30803
# iteration 30853
# iteration 30903
# iteration 30953
# iteration 31003
# iteration 31053
# iteration 31103
# iteration 31153
# iteration 31203
# iteration 31253
# iteration 31303
# iteration 31353
# iteration 31403
# iteration 31453
# iteration 31503
# iteration 31553
# iteration 31603
# iteration 31653
# iteration 31703
# iteration 31753
# iteration 31803
# iteration 31853
# iteration 31903
# iteration 31953
# iteration 32003
# iteration 32053
# iteration 32103
# iteration 32153
# iteration 32203
# iteration 32253
# iteration 32303
# iteration 32353
# iteration 32403
# iteration 32453
# iteration 32503
# iteration 32553
# iteration 32603
# iteration 32653
# iteration 32703
# iteration 32753
# iteration 32803
# iteration 32853
# iteration 32903
# iteration 32953
# iteration 33003
# iteration 33053
# iteration 33103
# iteration 33153
# iteration 33203
# iteration 33253
# iteration 33303
# iteration 33353
# iteration 33403
# iteration 33453
# iteration 33503
# iteration 33553
# iteration 33603
# iteration 33653
# iteration 33703
# iteration 33753
# iteration 33803
# iteration 33853
# iteration 33903
# iteration 33953
# iteration 34003
# iteration 34053
# iteration 34103
# iteration 34153
# iteration 34203
# iteration 34253
# iteration 34303
# iteration 34353
# iteration 34403
# iteration 34453
# iteration 34503
# iteration 34553
# iteration 34603
# iteration 34653
# iteration 34703
# iteration 34753
# iteration 34803
# iteration 34853
# iteration 34903
# iteration 34953
# iteration 35003
# iteration 35053
# iteration 35103
# iteration 35153
# iteration 35203
# iteration 35253
# iteration 35303
# iteration 35353
# iteration 35403
# iteration 35453
# iteration 35503
# iteration 35553
# iteration 35603
# iteration 35653
# iteration 35703
# iteration 35753
# iteration 35803
# iteration 35853
# iteration 35903
# iteration 35953
# iteration 36003
# iteration 36053
# iteration 36103
# iteration 36153
# iteration 36203
# iteration 36253
# iteration 36303
# iteration 36353
# iteration 36403
# iteration 36453
# iteration 36503
# iteration 36553
# iteration 36603
# iteration 36653
# iteration 36703
# iteration 36753
# iteration 36803
# iteration 36853
# iteration 36903
# iteration 36953
# iteration 37003
# iteration 37053
# iteration 37103
# iteration 37153
# iteration 37203
# iteration 37253
# iteration 37303
# iteration 37353
# iteration 37403
# iteration 37453
# iteration 37503
# iteration 37553
# iteration 37603
# iteration 37653
# iteration 37703
# iteration 37753
# iteration 37803
# iteration 37853
# iteration 37903
# iteration 37953
# iteration 38003
# iteration 38053
# iteration 38103
# iteration 38153
# iteration 38203
# iteration 38253
# iteration 38303
# iteration 38353
# iteration 38403
# iteration 38453
# iteration 38503
# iteration 38553
# iteration 38603
# iteration 38653
# iteration 38703
# iteration 38753
# iteration 38803
# iteration 38853
# iteration 38903
# iteration 38953
# iteration 39003
# iteration 39053
# iteration 39103
# iteration 39153
# iteration 39203
# iteration 39253
# iteration 39303
# iteration 39353
# iteration 39403
# iteration 39453
# iteration 39503
# iteration 39553
# iteration 39603
# iteration 39653
# iteration 39703
# iteration 39753
# iteration 39803
# iteration 39853
# iteration 39903
# iteration 39953
# iteration 40004
# iteration 40054
# iteration 40104
# iteration 40154
# iteration 40204
# iteration 40254
# iteration 40304
# iteration 40354
# iteration 40404
# iteration 40454
# iteration 40504
# iteration 40554
# iteration 40604
# iteration 40654
# iteration 40704
# iteration 40754
# iteration 40804
# iteration 40854
# iteration 40904
# iteration 40954
# iteration 41004
# iteration 41054
# iteration 41104
# iteration 41154
# iteration 41204
# iteration 41254
# iteration 41304
# iteration 41354
# iteration 41404
# iteration 41454
# iteration 41504
# iteration 41554
# iteration 41604
# iteration 41654
# iteration 41704
# iteration 41754
# iteration 41804
# iteration 41854
# iteration 41904
# iteration 41954
# iteration 42004
# iteration 42054
# iteration 42104
# iteration 42154
# iteration 42204
# iteration 42254
# iteration 42304
# iteration 42354
# iteration 42404
# iteration 42454
# iteration 42504
# iteration 42554
# iteration 42604
# iteration 42654
# iteration 42704
# iteration 42754
# iteration 42804
# iteration 42854
# iteration 42904
# iteration 42954
# iteration 43004
# iteration 43054
# iteration 43104
# iteration 43154
# iteration 43204
# iteration 43254
# iteration 43304
# iteration 43354
# iteration 43404
# iteration 43454
# iteration 43504
# iteration 43554
# iteration 43604
# iteration 43654
# iteration 43704
# iteration 43754
# iteration 43804
# iteration 43854
# iteration 43904
# iteration 43954
# iteration 44004
# iteration 44054
# iteration 44104
# iteration 44154
# iteration 44204
# iteration 44254
# iteration 44304
# iteration 44354
# iteration 44404
# iteration 44454
# iteration 44504
# iteration 44554
# iteration 44604
# iteration 44654
# iteration 44704
# iteration 44754
# iteration 44804
# iteration 44854
# iteration 44904
# iteration 44954
# iteration 45004
# iteration 45054
# iteration 45104
# iteration 45154
# iteration 45204
# iteration 45254
# iteration 45304
# iteration 45354
# iteration 45404
# iteration 45454
# iteration 45504
# iteration 45554
# iteration 45604
# iteration 45654
# iteration 45704
# iteration 45754
# iteration 45804
# iteration 45854
# iteration 45904
# iteration 45954
# iteration 46004
# iteration 46054
# iteration 46104
# iteration 46154
# iteration 46204
# iteration 46254
# iteration 46304
# iteration 46354
# iteration 46404
# iteration 46454
# iteration 46504
# iteration 46554
# iteration 46604
# iteration 46654
# iteration 46704
# iteration 46754
# iteration 46804
# iteration 46854
# iteration 46904
# iteration 46954
# iteration 47004
# iteration 47054
# iteration 47104
# iteration 47154
# iteration 47204
# iteration 47254
# iteration 47304
# iteration 47354
# iteration 47404
# iteration 47454
# iteration 47504
# iteration 47554
# iteration 47604
# iteration 47654
# iteration 47704
# iteration 47754
# iteration 47804
# iteration 47854
# iteration 47904
# iteration 47954
# iteration 48004
# iteration 48054
# iteration 48104
# iteration 48154
# iteration 48204
# iteration 48254
# iteration 48304
# ----------------------------------------------------------------------
# KeyboardInterrupt                    Traceback (most recent call last)
# <ipython-input-35-9eb0dddeb79b> in <module>
#      18     ind = index_list[arm]
#      19     area = (2*M/2**ll[0])*(2*M/2**ll[1])
# ---> 20     total = (pp[ind]*area).sum()
#      21     weights = total/max(len(ind),1)
#      22
#
# KeyboardInterrupt:

# %%
np.savez(save_path + 'out_0.npz', Z_hat = Z_hat,\
         children = children, explorefactor = explorefactor, alpha = alpha, q = q,\
         num_partition = num_partition, total_ESS = total_ESS)
# Out:
# 0.9

# %% [markdown]
# # Plotting proposal distribution

# %%
colors = []
for i in range(len(children)):
    node = np.array(children[i])
    ll = np.floor(np.log2(node+1))
    area = (2*M/2**ll[0])*(2*M/2**ll[1])
    colors.append(q[i]/area)

import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib
matplotlib.rcParams.update({'font.size': 12})


minima = min(colors)
maxima = max(colors)

norm = mpl.colors.Normalize(vmin=minima, vmax=maxima, clip=True)
cmap_reversed = mpl.cm.get_cmap('hot_r')
mapper = cm.ScalarMappable(norm=norm, cmap=cmap_reversed)


fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim((-10,10))
ax.set_ylim((-2,6))
plt.xticks([], [])
plt.yticks([], [])
count = 0
for i in children:
    ss = get_ss(i)
    i=np.array(i)
    ll = np.floor(np.log2(i+1))
    area = (2*M/2**ll[0])*(2*M/2**ll[1])
    #ss = (i+1-2**ll)/2**ll*2*M - M
    ax.add_patch(
        patches.Rectangle((ss[0], ss[1]),  2*M/(2**ll[0]),   2*M/(2**ll[1]) , \
                          edgecolor='black',alpha = 0.8,
                          facecolor = (mapper.to_rgba(q[count]/area)[:-1])))
    count += 1

seed = 1
save_path = './results/alpha_%s_explore_%s/' %(alpha, explorefactor)    
plt.tight_layout()    
#plt.savefig(save_path + 'proposal_%d.pdf' %seed) 
#plt.savefig('banana_%s_%s.eps' %(alpha, explorefactor) )
#plt.savefig('banana_%s_%s.png' %(alpha, explorefactor) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a59e28c2c5a3> in <module>
#       1 colors = []
# ----> 2 for i in range(len(children)):
#       3     node = np.array(children[i])
#       4     ll = np.floor(np.log2(node+1))
#       5     area = (2*M/2**ll[0])*(2*M/2**ll[1])
#
# NameError: name 'children' is not defined

# %%
plt.hist2d(xx[0,:tt], xx[1,:tt], bins=(50, 50), cmap='hot_r')
plt.ylim([-2,6])
plt.tight_layout()
#plt.savefig(save_path + 'empirical_%d.pdf' %seed)

# %%
np.savez(save_path + 'out_%d.npz' %seed, Z_hat = Z_hat,\
         children = children, explorefactor = explorefactor, alpha = alpha, q = q,\
         num_partition = num_partition, total_ESS = total_ESS)

# %%
save_path + 'out_%d.npz'
# Out:
# './results/alpha_0.5_explore_0.1/out_%d.npz'

# %% [markdown]
# # Plotting true distribution

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


#plt.xticks([], [])
#plt.yticks([], [])  
#ax.set_xlim((-M,M))
#ax.set_ylim((-M,M))
#plt.show()

def true_p(x, y):
    return  np.exp(-0.5*(0.03*x**2+(y+0.03*(x**2-100))**2))
  
aa, bb = np.meshgrid(np.linspace(-15,15,100), np.linspace(-15,15,130))
ww = true_p(aa, bb)


plt.contour(aa, bb, ww, cmap = cmap_reversed);
#plt.imshow(ww, extent=[-M, M, -M, M], cmap = cmap_reversed);

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)


zz = np.zeros((100,130))
aa = np.linspace(-10,10,100)
bb = np.linspace(-10,10,130)
for i in range(130):
	for j in range(100):
		zz[99-j,129-i] = truep([bb[i],aa[j]])
	

ax.imshow(zz, cmap = cmap_reversed, interpolation='nearest')
#plt.xticks([], [])
#plt.yticks([], [])  
plt.ylim([60,20])
plt.show()

# %%
plt.plot(np.arange(len(total_ESS))*1000, total_ESS)
plt.xlabel('Iteration')
plt.ylabel('ESS')
# Out:
# Text(0, 0.5, 'ESS')

# %%
def mv(x):
    y = []
    for j in range(1000):
        y.append(x[j])    
    for j in range(1000,len(x)):
        y.append(np.mean(x[(j-100):j]))
    return(np.array(y))

# %%
#pimais_mean = mv(pimais_mean)
#Z_hat = mv(Z_hat)




Z = 33.255484747422330

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
iterations = np.linspace(1000,1000*len(Z_hat), len(Z_hat))
ax.plot(iterations,(np.array(Z_hat) - Z)**2,linewidth=2.0, label="HiDaisee",color="blue")
ax.plot(pimais_iterations,(pimais_mean - Z)**2,linewidth=2.0, label="PIMAIS",color="orange",linestyle='-.')
plt.legend(fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("iteration",fontsize=20)
plt.ylabel("squared error",fontsize=20)
#plt.xscale("log")
plt.yscale("log")
plt.xlim([0,1e5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-a9bb6d55588a> in <module>
#      13 iterations = np.linspace(1000,1000*len(Z_hat), len(Z_hat))
#      14 ax.plot(iterations,(np.array(Z_hat) - Z)**2,linewidth=2.0, label="HiDaisee",color="blue")
# ---> 15 ax.plot(pimais_iterations,(pimais_mean - Z)**2,linewidth=2.0, label="PIMAIS",color="orange",linestyle='-.')
#      16 plt.legend(fontsize=20)
#      17 plt.tick_params(axis='both', which='major', labelsize=15)
#
# NameError: name 'pimais_iterations' is not defined

# %% [markdown]
# # Load saved results

# %%
saved_path = './results/alpha_0.9_explore_3.0/'
def collect_Z_hat(saved_path):
    out = []
    for i in range(1,11):
        try:
            tmp = np.load(saved_path + 'out_%d.npz' %i)['Z_hat']
            out.append(tmp)
        except:
            print('data not available %d' %i)

    out = np.reshape(out, (len(out), len(out[0])))
    out = np.median(out,axis = 0)
    return out

# %%
out_50 = collect_Z_hat('./results/alpha_0.5_explore_3.0/')

# %%
out_90 = collect_Z_hat('./results/alpha_0.9_explore_3.0/')

# %%
out_99 = collect_Z_hat('./results/alpha_0.99_explore_3.0/')

# %%
def mv(x):
    y = []
    for j in range(100):
        y.append(x[j])    
    for j in range(100,len(x)):
        y.append(np.mean(x[(100):j]))
    return(np.array(y))

# %%
import pandas as pd
pimais_path = '/Users/luxiaoyu/Downloads/pimais/pimais_z.csv'

pimais = np.array(pd.read_csv(pimais_path, sep=',',header=None))

pimais_mean = np.mean(np.exp(pimais[:,:10]),1)
pimais_mean = mv(pimais_mean)

iterations_pimais = np.array([int(x) for x in np.linspace(0, 5e5, 10000)])

out_90 = mv(out_90)
out_99 = mv(out_99)
out_50 = mv(out_50)
# Out:
# /Users/luxiaoyu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/luxiaoyu/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import matplotlib
font = {'weight' : 'bold',
        'size'   : 20}

matplotlib.rc('font', **font)

Z = 33.255484747422330

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

iterations_pimais = np.array([int(x) for x in np.linspace(0, 5e5, 10000)])
subset_pimais = np.array([int(x) for x in np.linspace(1, len(iterations_pimais)-1, 100)])
#subset_pimais = np.array([int(x) for x in np.logspace(1, np.log10(len(iterations_pimais)-1), 200)])
iterations = iterations_pimais[:len(out_90)]
subset = np.array([int(x) for x in np.linspace(1, len(iterations)-1, 1000)])
#subset = np.array([int(x) for x in np.logspace(1, np.log10(len(iterations)-1), 200)])




#iterations_Z_hat  = iterations_pimais[:len(Z_hat)]
#ax.plot(iterations_Z_hat,(np.array(Z_hat) - Z)**2,linewidth=2.0, label="HiDaisee",color="blue")
ax.plot(iterations[subset],(np.array(out_50[subset]) - Z)**2,linewidth=2.0, label=r'HiDaisee, $\lambda = 0.5$',color="green")
ax.plot(iterations[subset],(np.array(out_90[subset]) - Z)**2,linewidth=2.0, label=r'HiDaisee, $\lambda = 0.9$',color="blue")
ax.plot(iterations[subset],(np.array(out_99[subset]) - Z)**2,linewidth=2.0, label=r'HiDaisee, $\lambda = 0.99$',color="red")
ax.plot(iterations_pimais[subset_pimais],(pimais_mean[subset_pimais]- Z)**2,linewidth=2.0, \
        label="PIMAIS",color="orange",linestyle='-.')

plt.legend(fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("Number of Samples",fontsize=25)
plt.ylabel("Squared Error",fontsize=25)
#plt.xscale("log")
plt.yscale("log")
#plt.xlim([1000, 5e5])
ax.ticklabel_format(style='sci',scilimits=(-3,4),axis='x')
ax.xaxis.major.formatter._useMathText = True

plt.tight_layout()
plt.savefig('./plots/compare1.pdf')

# %%
iterations

# %%
#pimais_mean = mv(pimais_mean)
#out_90 = mv(out_90)

Z = 33.255484747422330

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

iterations_pimais = np.array([int(x) for x in np.linspace(0, 5e5, 10000)])
subset_pimais = np.array([int(x) for x in np.linspace(1, len(iterations_pimais)-1, 100)])
subset_pimais = np.array([int(x) for x in np.logspace(1, np.log10(len(iterations_pimais)-1), 100)])


iterations = iterations_pimais[:len(out_90)]
subset = np.array([int(x) for x in np.linspace(1, len(iterations)-1, 100)])
subset = np.array([int(x) for x in np.logspace(1, np.log10(len(iterations)-1), 100)])




iterations_Z_hat  = iterations_pimais[:len(Z_hat)]
ax.plot(iterations_Z_hat,(np.array(Z_hat) - Z)**2,linewidth=2.0, label="HiDaisee",color="blue")
#ax.plot(iterations[subset],(np.array(out_50[subset]) - Z)**2,linewidth=2.0, label="50",color="green")
ax.plot(iterations,(np.array(out_90) - Z)**2,linewidth=2.0, label="90",color="red")
#ax.plot(iterations,(np.array(out_99) - Z)**2,linewidth=2.0, label="99",color="black")
ax.plot(iterations_pimais,(pimais_mean- Z)**2,linewidth=2.0, \
        label="PIMAIS",color="orange",linestyle='-.')

plt.legend(fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("iteration",fontsize=20)
plt.ylabel("squared error",fontsize=20)
plt.xscale("log")
plt.yscale("log")
#plt.ylim([1e-3, 1e3])

# %% [markdown]
# # ESS plot

# %%
def collect_ESS(saved_path):
    out = []
    for i in range(1,11):
        try:
            tmp = np.load(saved_path + 'out_%d.npz' %i)['total_ESS']
            out.append(tmp)
        except:
            print('data not available %d' %i)

    out = np.reshape(out, (len(out), len(out[0])))
    out = out.mean(axis = 0)
    return out

# %%
ess_50 = collect_ESS('./results/alpha_0.5_explore_3.0/')
ess_90 = collect_ESS('./results/alpha_0.9_explore_3.0/')
ess_99 = collect_ESS('./results/alpha_0.99_explore_3.0/')

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

iterations = np.array([int(x) for x in np.linspace(0, 5e5, 10000)])
iterations = iterations_pimais[:len(ess_90)]

ax.plot(iterations,ess_50,linewidth=2.0, label=r'$\lambda = 0.5$',color="green")
ax.plot(iterations,ess_90,linewidth=2.0, label=r'$\lambda = 0.9$',color="blue")
ax.plot(iterations,ess_99,linewidth=2.0, label=r'$\lambda = 0.99$',color="red")

plt.legend(loc=4,fontsize=30)
plt.tick_params(axis='both', which='major')
plt.xlabel("Number of Samples",fontsize = 25)
plt.ylabel("ESS",fontsize = 25)
plt.xscale("log")
plt.tight_layout()
plt.savefig('./plots/ess.pdf')

# %% [markdown]
# # Number of Partitions plot

# %%
def collect_partition(saved_path):
    out = []
    for i in range(1):
        try:
            tmp = np.load(saved_path + 'out_%d.npz' %i)['num_partition']
            out.append(tmp)
        except:
            print('data not available %d' %i)

    out = np.reshape(out, (len(out), len(out[0])))
    out = out.mean(axis = 0)
    return out

# %%
par_50 = collect_partition('./results/alpha_0.5_explore_3.0/')
par_90 = collect_partition('./results/alpha_0.9_explore_3.0/')
par_99 = collect_partition('./results/alpha_0.99_explore_3.0/')

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)


#subset = np.array([int(x) for x in np.linspace(1, len(iterations)-1, 100)])
subset = np.array([int(x) for x in np.logspace(1, np.log10(len(iterations)-1), 50)])



ax.plot(iterations[subset],par_50[subset],linewidth=2.0, label=r'$\lambda = 0.5$',color="green")
ax.plot(iterations[subset],par_90[subset],linewidth=2.0, label=r'$\lambda = 0.9$',color="blue")
ax.plot(iterations[subset],par_99[subset],linewidth=2.0, label=r'$\lambda = 0.99$',color="red")

plt.legend(loc=4,fontsize=30)
plt.tick_params(axis='both', which='major')
plt.xlabel("Number of Samples",fontsize = 25)
plt.ylabel("Number of Partitions",fontsize = 25)
plt.xscale("log")
plt.tight_layout()
plt.savefig('./plots/partition.pdf')

# %% [markdown]
# # Tuning hyperparameter

# %%
def collect_Z_hat_runing():
    saved_path = './results/alpha_0.9_explore_'
    out = []
    for i in range(1,41):
        try:
            i = 0.1*i
            out.append(np.load(saved_path + '%.1f/out_1.npz' %i)['Z_hat'])
        except:
            pass

    out = np.reshape(out, (len(out), len(out[0])))
    return out

# %%
out = collect_Z_hat_runing()

# %%
out = out.mean(axis = 0)

# %%
out.shape
# Out:
# (9998,)

# %%
#pimais_mean = mv(pimais_mean)
#Z_hat = mv(out)

Z = 33.255484747422330

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

iterations_pimais = np.array([int(x) for x in np.linspace(0, 5e5, 10000)])
#iterations = iterations_pimais[:len(out[0])]
iterations = iterations_pimais[:len(out)]


#for i in range(15,20):    
#    ax.plot(iterations,(np.array(out[i,:]) - Z)**2,linewidth=2.0, label=i)
ax.plot(iterations_pimais,(pimais_mean- Z)**2,linewidth=2.0, label="PIMAIS",color="orange",linestyle='-.')
ax.plot(iterations,(out- Z)**2,linewidth=2.0, label="PIMAIS",color="red",linestyle='-.')


plt.legend(fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("iteration",fontsize=20)
plt.ylabel("squared error",fontsize=20)
plt.xscale("log")
plt.yscale("log")
#plt.xlim([1e3, 1e6])
